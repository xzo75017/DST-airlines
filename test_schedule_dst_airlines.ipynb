# %%
#Test de la table schedule 

import requests 
import pandas as pd
def Flight_Schedules():
    liste_schedule_Total_Journey = []
    liste_schedule_Flight = []
    schedule = requests.get('https://api.lufthansa.com/v1/operations/schedules/ZRH/FRA/2023-04-14?directFlights=0', headers={'Authorization': 'Bearer 6sqdpy6tzgfahhwrvgn3e8q2'}).json()
    print(schedule['ScheduleResource']['Schedule'][15]['Flight'][0])
    #schedule_df = pd.DataFrame(schedule['ScheduleResource']['Schedule'][0]['Flight'])
    for i in range(len(schedule['ScheduleResource']['Schedule'])):
        liste_schedule_Total_Journey.append(schedule['ScheduleResource']['Schedule'][i]['TotalJourney'])
        if type(schedule['ScheduleResource']['Schedule'][i]['Flight']) is dict:
            liste_schedule_Flight.append(schedule['ScheduleResource']['Schedule'][i]['Flight'])
        elif type(schedule['ScheduleResource']['Schedule'][i]['Flight'] is list):
            liste_schedule_Flight.append(schedule['ScheduleResource']['Schedule'][i]['Flight'][0])

    Schedule_Total_Journey_df = pd.DataFrame(liste_schedule_Total_Journey)
    Schedule_Flight_df = pd.DataFrame(liste_schedule_Flight)
    def AirportCode_d(Departure):
        return Departure.get('AirportCode',{})

    def ScheduledTimeLocal(Departure):
        return Departure.get('ScheduledTimeLocal',{})

    def AirportCode_a(Arrival):
        return Arrival.get('AirportCode',{})

    def ScheduledTimeLocal(Arrival):
        return Arrival.get('ScheduledTimeLocal',{}).get('DateTime',{})

    #def Name(Terminal):
        #return Terminal.get('Name',{})
    def AirlineID(MarketingCarrier):
        return MarketingCarrier.get('AirlineID',{})
    def FlightNumber(MarketingCarrier):
        return MarketingCarrier.get('FlightNumber',{})
    
    #A mettre lOperating Carrier 
    #for x in Schedule_Flight_df['OperatingCarrier']:
     #   if x is dict:
       #     def AirlineID(OperatingCarrier):
       #         return OperatingCarrier.get('AirlineID,{}')
      #  else:
          #  None
    

    def AircraftCode(Equipment):
        return Equipment.get('AircraftCode',{})    
    def StopQuantity(Details):
        return Details.get('StopQuantity')
    
       
    def DaysOfOperation(Details):
        return Details.get('DaysOfOperation',{})
    
       
    def Effective(Details):
        return Details.get('DatePeriod',{}).get('Effective',{})    
    def Expiration(Details):
        return Details.get('DatePeriod',{}).get('Expiration',{}) 
       

    Schedule_Flight_df['AirportCode_Departure'] = Schedule_Flight_df['Departure'].apply(AirportCode_d)

    Schedule_Flight_df['ScheduledTimeLocal_Departure'] = Schedule_Flight_df['Departure'].apply(ScheduledTimeLocal)

    Schedule_Flight_df['AirportCode_Arrival'] = Schedule_Flight_df['Arrival'].apply(AirportCode_a)
#A mettre le nom du terminal
    #Schedule_Flight_df['Name_Terminal'] = Schedule_Flight_df['Name_Terminal'].apply(Name)

    Schedule_Flight_df['AirlineID_Marketing_Carrier'] = Schedule_Flight_df['MarketingCarrier'].apply(AirlineID)

    Schedule_Flight_df['FlightNumber'] = Schedule_Flight_df['MarketingCarrier'].apply(FlightNumber)
 #A mettre lOperating Carrier   
    #Schedule_Flight_df['AirlineID_Operating_Carrier'] = Schedule_Flight_df['OperatingCarrier'].apply(FlightNumber)
    Schedule_Flight_df['AircraftCode'] = Schedule_Flight_df['Equipment'].apply(AircraftCode)
    Schedule_Flight_df['StopQuantity'] = Schedule_Flight_df['Details'].apply(StopQuantity)
    Schedule_Flight_df['DaysOfOperation'] = Schedule_Flight_df['Details'].apply(DaysOfOperation)
    Schedule_Flight_df['Effective'] = Schedule_Flight_df['Details'].apply(Effective)
    Schedule_Flight_df['Expiration'] = Schedule_Flight_df['Details'].apply(Expiration)

    Schedule_Flight_df = Schedule_Flight_df.drop(['Departure', 'Arrival','MarketingCarrier', 'OperatingCarrier', 'Equipment','Details'], axis = 1)
    Schedule_Flight_df.head()


 
    return Schedule_Flight_df, Schedule_Total_Journey_df

# %%
Schedule_Flight_df, Schedule_Total_Journey_df = Flight_Schedules()
# Out:
# {'Departure': {'AirportCode': 'ZRH', 'ScheduledTimeLocal': {'DateTime': '2023-04-14T07:10'}}, 'Arrival': {'AirportCode': 'HAM', 'ScheduledTimeLocal': {'DateTime': '2023-04-14T08:40'}, 'Terminal': {'Name': '2'}}, 'MarketingCarrier': {'AirlineID': 'LX', 'FlightNumber': '1050'}, 'Equipment': {'AircraftCode': '221'}, 'Details': {'Stops': {'StopQuantity': 0}, 'DaysOfOperation': '5', 'DatePeriod': {'Effective': '2023-04-14', 'Expiration': '2023-04-14'}}}

# %%
Schedule_Flight_df
# Out:
#    AirportCode_Departure ScheduledTimeLocal_Departure AirportCode_Arrival  \
# 0                    ZRH             2023-04-14T07:00                 FRA
# 1                    ZRH             2023-04-14T08:15                 FRA
# 2                    ZRH             2023-04-14T09:35                 FRA
# 3                    ZRH             2023-04-14T11:20                 FRA
# 4                    ZRH             2023-04-14T12:10                 FRA
# 5                    ZRH             2023-04-14T14:40                 FRA
# 6                    ZRH             2023-04-14T18:05                 FRA
# 7                    ZRH             2023-04-14T19:05                 FRA
# 8                    ZRH             2023-04-14T20:00                 FRA
# 9                    ZRH             2023-04-14T07:10                 MUC
# 10                   ZRH             2023-04-14T07:10                 MUC
# 11                   ZRH             2023-04-14T07:10                 VIE
# 12                   ZRH             2023-04-14T07:10                 HAM
# 13                   ZRH             2023-04-14T07:10                 MUC
# 14                   ZRH             2023-04-14T07:10                 MUC
# 15                   ZRH             2023-04-14T07:10                 HAM
# 16                   ZRH             2023-04-14T07:10                 HAJ
# 17                   ZRH             2023-04-14T07:10                 VIE
#
#    AirlineID_Marketing_Carrier FlightNumber AircraftCode StopQuantity  \
# 0                           LH         5737          223         None
# 1                           LH         1183          32A         None
# 2                           LH         1185          CR9         None
# 3                           LH         1187          319         None
# 4                           LH         5739          E90         None
# 5                           LH         1191          319         None
# 6                           LH         1197          319         None
# 7                           LH         5741          32N         None
# 8                           LH         1199          319         None
# 9                           LX         1100          295         None
# 10                          LH         5749          295         None
# 11                          OS          568          320         None
# 12                          LX         1050          221         None
# 13                          LX         1100          295         None
# 14                          LH         5749          295         None
# 15                          LX         1050          221         None
# 16                          LX          814          E90         None
# 17                          OS          568          320         None
#
#    DaysOfOperation   Effective  Expiration
# 0            12345  2023-04-14  2023-04-20
# 1                5  2023-04-14  2023-04-14
# 2                5  2023-04-14  2023-04-28
# 3             1567  2023-04-14  2023-04-17
# 4                5  2023-04-14  2023-04-14
# 5               25  2023-04-14  2023-04-21
# 6             2357  2023-04-14  2023-04-19
# 7                5  2023-04-14  2023-04-28
# 8               15  2023-04-14  2023-04-21
# 9               15  2023-04-14  2023-04-17
# 10              15  2023-04-14  2023-04-17
# 11         1234567  2023-04-14  2023-04-21
# 12               5  2023-04-14  2023-04-14
# 13             145  2023-04-14  2023-04-20
# 14             145  2023-04-14  2023-04-20
# 15               5  2023-04-14  2023-04-14
# 16               5  2023-04-14  2023-04-14
# 17             456  2023-04-14  2023-04-21
