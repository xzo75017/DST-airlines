# %%
import pandas as pd
import requests
from datetime import datetime, timedelta
def arrival():
    airports_codes= ["FRA","BER","JFK"]
    d = '2023-04-28T12:30'

    dt = datetime.strptime(d, '%Y-%m-%dT%H:%M')
    
    while dt< datetime.now() :
        g = dt+timedelta(days = 1)
        dt = g
        g = g.strftime("%Y-%m-%dT%H:%M")

        print(g)
        list_arrival = []
        for airport_code in airports_codes:
            data_arrival_flight = requests.get(f'https://api.lufthansa.com/v1/operations/customerflightinformation/arrivals/{airport_code}/{g}' , headers={'Authorization': 'Bearer czdgawxxync46475qcdsg7qr'}).json()
    #Visualisation du fichier json on remarque que la liste est à data_arrival_flight['FlightInformation']['Flights']['Flight'] + visualisation des clés des dictionnaires
        #print(data_arrival_flight['FlightInformation']['Flights']['Flight'][0].keys())
    #Boucle sur chaque élément de la liste
            for i in range(len(data_arrival_flight['FlightInformation']['Flights']['Flight'])):
#Visualisation des différentes variables contenues dans la liste
                print(data_arrival_flight['FlightInformation']['Flights']['Flight'][0])
        #liste_Departure.append(data_arrival_flight['FlightInformation']['Flights']['Flight'][i]['Departure'])
        #liste_departure_schedule.append(data_arrival_flight['FlightInformation']['Flights']['Flight'][i]['Departure']['Scheduled'])
        #liste_departure_actual.append(data_arrival_flight['FlightInformation']['Flights']['Flight'][i]['Arrival']['Actual'])
                list_arrival.append(data_arrival_flight['FlightInformation']['Flights']['Flight'][i])
        #liste_terminal.append(data_arrival_flight['FlightInformation']['Flights']['Flight'][i]['Departure']['Terminal'])
        #liste_arrival_status.append(data_arrival_flight['FlightInformation']['Flights']['Flight'][i]['Departure']['Status'])
    #Departure = pd.DataFrame(liste_Departure)
    #Departure_Scheduled = pd.DataFrame(liste_departure_schedule)
    #Arrival_Actual  = pd.DataFrame(liste_arrival_actual)
    Arrival = pd.DataFrame(list_arrival)


    def AirportCode_de(Departure):
        return Departure.get('AirportCode',{})

    def Scheduled_date_de(Departure):
        return Departure.get('Scheduled',{}).get('Date',{})
    
    def Scheduled_time_de(Departure):
        return Departure.get('Scheduled',{}).get('Time',{})

    def Scheduled_date_ae(Arrival):
        return Arrival.get('Scheduled',{}).get('Date',{})
    
    def Scheduled_time_ae(Arrival):
        return Arrival.get('Scheduled',{}).get('Time',{})

    def Name(Arrival):
        return Arrival.get('Terminal',{}).get('Name',{})
    
    def AirportCode_ae(Arrival):
        return Arrival.get('AirportCode',{})
    
    def estimated_date_ae(Arrival):
        return Arrival.get('Estimated',{}).get('Time',{})
    
    def estimated_time_ae(Arrival):
        return Arrival.get('Estimated',{}).get('Date',{})
    
    def actual_time_ae(Arrival):
        return Arrival.get('Actual',{}).get('Time',{})
    
    def actual_date_ae(Arrival):
        return Arrival.get('Actual',{}).get('Date',{})
    
    def actual_time_de(Departure):
        return Departure.get('Actual',{}).get('Time',{})
    
    def actual_date_de(Departure):
        return Departure.get('Actual',{}).get('Date',{})
    
       
    for i in range(len(data_arrival_flight['FlightInformation']['Flights']['Flight'][0]['MarketingCarrierList'])):
        def AirlineID_mark(MarketingCarrierList):
            return MarketingCarrierList.get('MarketingCarrier',{})[i]

    def FlightNumber(MarketingCarrierList):
        return MarketingCarrierList.get('MarketingCarrier',{})
    
    def AirlineID(OperatingCarrier):
        return OperatingCarrier.get('AirlineID',{})
    
    def FlightNumber(OperatingCarrier):
        return OperatingCarrier.get('FlightNumber',{})
   
    def AircraftCode(Equipment):
        return Equipment.get('AircraftCode',{}) 
       
    def Status_Code_d(Departure):
        return Departure.get('Status',{}).get('Code',{})
    
    def Status_Description_d(Departure):
        return Departure.get('Status',{}).get('Description',{})
    

    def Status_Code_a(Arrival):
        return Arrival.get('Status',{}).get('Code',{})
    
    def Status_Description_a(Arrival):
        return Arrival.get('Status',{}).get('Description',{})
    

    
    #def AirlineID_Marketing_Carrier_(AirlineID_Marketing_Carrier):
    #    return AirlineID_Marketing_Carrier.get('AirlineID')
    
    #def Flight_Number_Marketing_Carrier_(AirlineID_Marketing_Carrier):
    #    return AirlineID_Marketing_Carrier.get('FlightNumber')  
        #Terminal_Departure = pd.DataFrame(liste_terminal)

    Arrival['AirportCode_Departure'] = Arrival['Departure'].apply(AirportCode_de)
    Arrival['ScheduledDateLocal_Departure'] = Arrival['Departure'].apply(Scheduled_date_de)
    Arrival['ScheduledTimeLocal_Departure'] = Arrival['Departure'].apply(Scheduled_time_de)
    Arrival['ScheduledDateLocal_Arrival'] = Arrival['Arrival'].apply(Scheduled_date_ae)
    Arrival['ScheduledTimeLocal_Arrival'] = Arrival['Arrival'].apply(Scheduled_time_ae)
    Arrival['AirportCode_Arrival'] = Arrival['Arrival'].apply(AirportCode_ae)
    Arrival['Name_Terminal'] = Arrival['Arrival'].apply(Name)
    Arrival['Estimated_date_arrival'] = Arrival['Arrival'].apply(estimated_date_ae)
    Arrival['Estimated_time_arrival'] = Arrival['Arrival'].apply(estimated_time_ae)
    Arrival['Actual_date_arrival'] = Arrival['Arrival'].apply(actual_date_ae)
    Arrival['Actual_time_arrival'] = Arrival['Arrival'].apply(actual_time_ae)
    Arrival['Actual_date_departure'] = Arrival['Departure'].apply(actual_date_de)
    Arrival['Actual_time_departure'] = Arrival['Departure'].apply(actual_time_de)
    #Departure_departure['AirlineID_Marketing_Carrier'] = Departure_departure['MarketingCarrierList'].apply(AirlineID_mark)
    #Departure_departure['AirlineID_Marketing_Carrier_'] = Departure_departure['AirlineID_Marketing_Carrier'].apply(AirlineID_Marketing_Carrier_)
    #Departure_departure['FlightNumber_Marketing_Carrier'] = Departure_departure['AirlineID_Marketing_Carrier'].apply(Flight_Number_Marketing_Carrier_)
    Arrival['AirlineID_Operating_Carrier'] = Arrival['OperatingCarrier'].apply(AirlineID)
    Arrival['FlightNumber_Operating_Carrier'] = Arrival['OperatingCarrier'].apply(FlightNumber)
    Arrival['AircraftCode'] = Arrival['Equipment'].apply(AircraftCode)
    Arrival['Status_Code_Departure'] = Arrival['Departure'].apply(Status_Code_d)
    Arrival['Status_Description_Departure'] = Arrival['Departure'].apply(Status_Description_d)
    Arrival['Status_Code_Arrival'] = Arrival['Arrival'].apply(Status_Code_a)
    Arrival['Status_Description_Arrival'] = Arrival['Arrival'].apply(Status_Description_a)
    Arrival = Arrival.drop(['Departure',	'Arrival',	'OperatingCarrier',	'Equipment','Status', 'MarketingCarrierList'], axis = 1)

    #Terminal = pd.DataFrame(liste_terminal)
        #Terminal = pd.DataFrame(liste_terminal)
    return Arrival

# %%
Arrival = arrival()
# Out:
# 2023-04-29T12:30
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'DEN', 'Scheduled': {'Date': '2023-04-28', 'Time': '17:35'}, 'Estimated': {'Date': '2023-04-28', 'Time': '19:25'}, 'Terminal': {'Gate': 'A41'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'Arrival': {'AirportCode': 'FRA', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:30'}, 'Estimated': {'Date': '2023-04-29', 'Time': '13:15'}, 'Actual': {'Date': '2023-04-29', 'Time': '13:15'}, 'Terminal': {'Name': '1', 'Gate': 'Z66'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '8879'}}, 'OperatingCarrier': {'AirlineID': 'LH', 'FlightNumber': '447'}, 'Equipment': {'AircraftCode': '343'}, 'Status': {'Code': 'DL', 'Description': 'Flight Delayed'}}
# {'Departure': {'AirportCode': 'CGN', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:25'}, 'Actual': {'Date': '2023-04-29', 'Time': '11:25'}, 'Terminal': {'Name': '1', 'Gate': 'D10'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'BER', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:35'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:35'}, 'Terminal': {'Name': '1', 'Gate': 'A35'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'OperatingCarrier': {'AirlineID': 'EW', 'FlightNumber': '006'}, 'Equipment': {'AircraftCode': '31D'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'CGN', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:25'}, 'Actual': {'Date': '2023-04-29', 'Time': '11:25'}, 'Terminal': {'Name': '1', 'Gate': 'D10'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'BER', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:35'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:35'}, 'Terminal': {'Name': '1', 'Gate': 'A35'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'OperatingCarrier': {'AirlineID': 'EW', 'FlightNumber': '006'}, 'Equipment': {'AircraftCode': '31D'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'CGN', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:25'}, 'Actual': {'Date': '2023-04-29', 'Time': '11:25'}, 'Terminal': {'Name': '1', 'Gate': 'D10'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'BER', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:35'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:35'}, 'Terminal': {'Name': '1', 'Gate': 'A35'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'OperatingCarrier': {'AirlineID': 'EW', 'FlightNumber': '006'}, 'Equipment': {'AircraftCode': '31D'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'CGN', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:25'}, 'Actual': {'Date': '2023-04-29', 'Time': '11:25'}, 'Terminal': {'Name': '1', 'Gate': 'D10'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'BER', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:35'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:35'}, 'Terminal': {'Name': '1', 'Gate': 'A35'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'OperatingCarrier': {'AirlineID': 'EW', 'FlightNumber': '006'}, 'Equipment': {'AircraftCode': '31D'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'CGN', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:25'}, 'Actual': {'Date': '2023-04-29', 'Time': '11:25'}, 'Terminal': {'Name': '1', 'Gate': 'D10'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'BER', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:35'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:35'}, 'Terminal': {'Name': '1', 'Gate': 'A35'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'OperatingCarrier': {'AirlineID': 'EW', 'FlightNumber': '006'}, 'Equipment': {'AircraftCode': '31D'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'CGN', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:25'}, 'Actual': {'Date': '2023-04-29', 'Time': '11:25'}, 'Terminal': {'Name': '1', 'Gate': 'D10'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'BER', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:35'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:35'}, 'Terminal': {'Name': '1', 'Gate': 'A35'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'OperatingCarrier': {'AirlineID': 'EW', 'FlightNumber': '006'}, 'Equipment': {'AircraftCode': '31D'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'CGN', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:25'}, 'Actual': {'Date': '2023-04-29', 'Time': '11:25'}, 'Terminal': {'Name': '1', 'Gate': 'D10'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'BER', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:35'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:35'}, 'Terminal': {'Name': '1', 'Gate': 'A35'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'OperatingCarrier': {'AirlineID': 'EW', 'FlightNumber': '006'}, 'Equipment': {'AircraftCode': '31D'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'CGN', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:25'}, 'Actual': {'Date': '2023-04-29', 'Time': '11:25'}, 'Terminal': {'Name': '1', 'Gate': 'D10'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'BER', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:35'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:35'}, 'Terminal': {'Name': '1', 'Gate': 'A35'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'OperatingCarrier': {'AirlineID': 'EW', 'FlightNumber': '006'}, 'Equipment': {'AircraftCode': '31D'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'CGN', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:25'}, 'Actual': {'Date': '2023-04-29', 'Time': '11:25'}, 'Terminal': {'Name': '1', 'Gate': 'D10'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'BER', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:35'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:35'}, 'Terminal': {'Name': '1', 'Gate': 'A35'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'OperatingCarrier': {'AirlineID': 'EW', 'FlightNumber': '006'}, 'Equipment': {'AircraftCode': '31D'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'CGN', 'Scheduled': {'Date': '2023-04-29', 'Time': '11:25'}, 'Actual': {'Date': '2023-04-29', 'Time': '11:25'}, 'Terminal': {'Name': '1', 'Gate': 'D10'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'BER', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:35'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:35'}, 'Terminal': {'Name': '1', 'Gate': 'A35'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'OperatingCarrier': {'AirlineID': 'EW', 'FlightNumber': '006'}, 'Equipment': {'AircraftCode': '31D'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'ZRH', 'Scheduled': {'Date': '2023-04-29', 'Time': '10:05'}, 'Actual': {'Date': '2023-04-29', 'Time': '10:05'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'JFK', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:45'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:45'}, 'Terminal': {'Name': '1'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '9718'}}, 'OperatingCarrier': {'AirlineID': 'LX', 'FlightNumber': '016'}, 'Equipment': {'AircraftCode': '333'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'ZRH', 'Scheduled': {'Date': '2023-04-29', 'Time': '10:05'}, 'Actual': {'Date': '2023-04-29', 'Time': '10:05'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'JFK', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:45'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:45'}, 'Terminal': {'Name': '1'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '9718'}}, 'OperatingCarrier': {'AirlineID': 'LX', 'FlightNumber': '016'}, 'Equipment': {'AircraftCode': '333'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'ZRH', 'Scheduled': {'Date': '2023-04-29', 'Time': '10:05'}, 'Actual': {'Date': '2023-04-29', 'Time': '10:05'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'JFK', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:45'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:45'}, 'Terminal': {'Name': '1'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '9718'}}, 'OperatingCarrier': {'AirlineID': 'LX', 'FlightNumber': '016'}, 'Equipment': {'AircraftCode': '333'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'ZRH', 'Scheduled': {'Date': '2023-04-29', 'Time': '10:05'}, 'Actual': {'Date': '2023-04-29', 'Time': '10:05'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'JFK', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:45'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:45'}, 'Terminal': {'Name': '1'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '9718'}}, 'OperatingCarrier': {'AirlineID': 'LX', 'FlightNumber': '016'}, 'Equipment': {'AircraftCode': '333'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'ZRH', 'Scheduled': {'Date': '2023-04-29', 'Time': '10:05'}, 'Actual': {'Date': '2023-04-29', 'Time': '10:05'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'JFK', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:45'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:45'}, 'Terminal': {'Name': '1'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '9718'}}, 'OperatingCarrier': {'AirlineID': 'LX', 'FlightNumber': '016'}, 'Equipment': {'AircraftCode': '333'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}
# {'Departure': {'AirportCode': 'ZRH', 'Scheduled': {'Date': '2023-04-29', 'Time': '10:05'}, 'Actual': {'Date': '2023-04-29', 'Time': '10:05'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'Arrival': {'AirportCode': 'JFK', 'Scheduled': {'Date': '2023-04-29', 'Time': '12:45'}, 'Actual': {'Date': '2023-04-29', 'Time': '12:45'}, 'Terminal': {'Name': '1'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}, 'MarketingCarrierList': {'MarketingCarrier': {'AirlineID': 'UA', 'FlightNumber': '9718'}}, 'OperatingCarrier': {'AirlineID': 'LX', 'FlightNumber': '016'}, 'Equipment': {'AircraftCode': '333'}, 'Status': {'Code': 'OT', 'Description': 'Flight On Time'}}

# %%
Arrival.head(100)
# Out:
#    AirportCode_Departure ScheduledDateLocal_Departure  \
# 0                    HAJ                   2023-04-29
# 1                    QDU                   2023-04-29
# 2                    BRI                   2023-04-29
# 3                    DUS                   2023-04-29
# 4                    BSL                   2023-04-29
# 5                    SKP                   2023-04-29
# 6                    CUN                   2023-04-28
# 7                    HAM                   2023-04-29
# 8                    LEJ                   2023-04-29
# 9                    OPO                   2023-04-29
# 10                   DRS                   2023-04-29
# 11                   QKL                   2023-04-29
# 12                   ZWS                   2023-04-29
# 13                   BER                   2023-04-29
# 14                   MUC                   2023-04-29
# 15                   AMS                   2023-04-29
# 16                   LHR                   2023-04-29
# 17                   MHJ                   2023-04-29
# 18                   BCN                   2023-04-29
# 19                   QWU                   2023-04-29
# 20                   STR                   2023-04-29
# 21                   FRA                   2023-04-29
# 22                   MUC                   2023-04-29
# 23                   ZRH                   2023-04-29
# 24                   BRU                   2023-04-29
# 25                   FRA                   2023-04-29
# 26                   PMI                   2023-04-29
# 27                   MUC                   2023-04-29
# 28                   CGN                   2023-04-29
# 29                   FRA                   2023-04-29
# 30                   ZRH                   2023-04-29
# 31                   BRU                   2023-04-29
#
#    ScheduledTimeLocal_Departure ScheduledDateLocal_Arrival  \
# 0                         08:35                 2023-04-29
# 1                         08:18                 2023-04-29
# 2                         07:30                 2023-04-29
# 3                         08:45                 2023-04-29
# 4                         08:35                 2023-04-29
# 5                         06:55                 2023-04-29
# 6                         16:00                 2023-04-29
# 7                         08:30                 2023-04-29
# 8                         08:40                 2023-04-29
# 9                         06:00                 2023-04-29
# 10                        08:45                 2023-04-29
# 11                        08:55                 2023-04-29
# 12                        08:39                 2023-04-29
# 13                        08:45                 2023-04-29
# 14                        09:00                 2023-04-29
# 15                        08:55                 2023-04-29
# 16                        07:30                 2023-04-29
# 17                        09:36                 2023-04-29
# 18                        08:00                 2023-04-29
# 19                        08:55                 2023-04-29
# 20                        08:25                 2023-04-29
# 21                        08:45                 2023-04-29
# 22                        09:00                 2023-04-29
# 23                        08:40                 2023-04-29
# 24                        09:25                 2023-04-29
# 25                        09:45                 2023-04-29
# 26                        08:25                 2023-04-29
# 27                        11:00                 2023-04-29
# 28                        11:25                 2023-04-29
# 29                        11:45                 2023-04-29
# 30                        10:05                 2023-04-29
# 31                        10:35                 2023-04-29
#
#    ScheduledTimeLocal_Arrival AirportCode_Arrival Name_Terminal  \
# 0                       09:30                 FRA             1
# 1                       09:33                 FRA            TN
# 2                       09:35                 FRA             1
# 3                       09:35                 FRA             1
# 4                       09:35                 FRA             1
# 5                       09:35                 FRA             1
# 6                       09:40                 FRA             1
# 7                       09:40                 FRA             1
# 8                       09:40                 FRA             1
# 9                       09:40                 FRA             1
# 10                      09:50                 FRA             1
# 11                      09:50                 FRA            TN
# 12                      09:51                 FRA            TN
# 13                      09:55                 FRA             1
# 14                      10:00                 FRA             1
# 15                      10:00                 FRA             1
# 16                      10:05                 FRA             1
# 17                      10:06                 FRA            TN
# 18                      10:10                 FRA             1
# 19                      10:20                 FRA            TN
# 20                      09:35                 BER             1
# 21                      09:55                 BER             1
# 22                      10:05                 BER             1
# 23                      10:05                 BER             1
# 24                      10:50                 BER             1
# 25                      10:55                 BER             1
# 26                      11:10                 BER             1
# 27                      12:05                 BER             1
# 28                      12:35                 BER             1
# 29                      12:55                 BER             1
# 30                      12:45                 JFK             1
# 31                      13:00                 JFK             1
#
#    Estimated_date_arrival Estimated_time_arrival Actual_date_arrival  \
# 0                      {}                     {}          2023-04-29
# 1                      {}                     {}          2023-04-29
# 2                      {}                     {}          2023-04-29
# 3                      {}                     {}          2023-04-29
# 4                      {}                     {}          2023-04-29
# 5                      {}                     {}          2023-04-29
# 6                      {}                     {}          2023-04-29
# 7                      {}                     {}          2023-04-29
# 8                      {}                     {}          2023-04-29
# 9                      {}                     {}          2023-04-29
# 10                     {}                     {}          2023-04-29
# 11                     {}                     {}          2023-04-29
# 12                     {}                     {}          2023-04-29
# 13                     {}                     {}          2023-04-29
# 14                     {}                     {}          2023-04-29
# 15                     {}                     {}          2023-04-29
# 16                     {}                     {}          2023-04-29
# 17                     {}                     {}          2023-04-29
# 18                     {}                     {}          2023-04-29
# 19                     {}                     {}          2023-04-29
# 20                     {}                     {}          2023-04-29
# 21                     {}                     {}          2023-04-29
# 22                     {}                     {}          2023-04-29
# 23                     {}                     {}          2023-04-29
# 24                     {}                     {}          2023-04-29
# 25                     {}                     {}          2023-04-29
# 26                     {}                     {}          2023-04-29
# 27                     {}                     {}          2023-04-29
# 28                     {}                     {}          2023-04-29
# 29                     {}                     {}          2023-04-29
# 30                     {}                     {}          2023-04-29
# 31                     {}                     {}          2023-04-29
#
#    Actual_time_arrival Actual_date_departure Actual_time_departure  \
# 0                09:30            2023-04-29                 08:35
# 1                09:33            2023-04-29                 08:18
# 2                09:35            2023-04-29                 07:30
# 3                09:35            2023-04-29                 08:45
# 4                09:35            2023-04-29                 08:35
# 5                09:35            2023-04-29                 06:55
# 6                09:40            2023-04-28                 16:00
# 7                09:40            2023-04-29                 08:30
# 8                09:40            2023-04-29                 08:40
# 9                09:40            2023-04-29                 06:00
# 10               09:50            2023-04-29                 08:45
# 11               09:50            2023-04-29                 08:55
# 12               09:51            2023-04-29                 08:39
# 13               09:55            2023-04-29                 08:45
# 14               10:00            2023-04-29                 09:00
# 15               10:00            2023-04-29                 08:55
# 16               10:05            2023-04-29                 07:30
# 17               10:06            2023-04-29                 09:36
# 18               10:10            2023-04-29                 08:00
# 19               10:20            2023-04-29                 08:55
# 20               09:35            2023-04-29                 08:25
# 21               09:55            2023-04-29                 08:45
# 22               10:05            2023-04-29                 09:00
# 23               10:05            2023-04-29                 08:40
# 24               10:50            2023-04-29                 09:25
# 25               10:55            2023-04-29                 09:45
# 26               11:10            2023-04-29                 08:25
# 27               12:05            2023-04-29                 11:00
# 28               12:35            2023-04-29                 11:25
# 29               12:55            2023-04-29                 11:45
# 30               12:45            2023-04-29                 10:05
# 31               13:00            2023-04-29                 10:35
#
#    AirlineID_Operating_Carrier FlightNumber_Operating_Carrier AircraftCode  \
# 0                           LH                            051          320
# 1                           2A                           3505          TRN
# 2                           4Y                            803          32A
# 3                           CL                            075          CR9
# 4                           CL                           1201          CR9
# 5                           LH                           1543          319
# 6                           4Y                            011          332
# 7                           LH                            009          32M
# 8                           LH                            159          319
# 9                           LH                           1181          32Q
# 10                          CL                            209          E90
# 11                          2A                           3607          TRN
# 12                          2A                           3557          TRN
# 13                          LH                            177          320
# 14                          LH                            099          320
# 15                          LH                            987          321
# 16                          LH                            923          32N
# 17                          2A                           3437          TRN
# 18                          LH                           1137          32M
# 19                          2A                           3469          TRN
# 20                          X8                           8001          320
# 21                          LH                            176          32A
# 22                          LH                           1934          32V
# 23                          LX                            976          320
# 24                          SN                           2581          319
# 25                          LH                            178          32M
# 26                          E6                           8593          320
# 27                          LH                           1936          321
# 28                          EW                            006          31D
# 29                          LH                            182          320
# 30                          LX                            016          333
# 31                          SN                            501          333
#
#    Status_Code_Departure Status_Description_Departure Status_Code_Arrival  \
# 0                     OT               Flight On Time                  OT
# 1                     OT               Flight On Time                  OT
# 2                     OT               Flight On Time                  OT
# 3                     OT               Flight On Time                  OT
# 4                     OT               Flight On Time                  OT
# 5                     OT               Flight On Time                  OT
# 6                     OT               Flight On Time                  OT
# 7                     OT               Flight On Time                  OT
# 8                     OT               Flight On Time                  OT
# 9                     OT               Flight On Time                  OT
# 10                    OT               Flight On Time                  OT
# 11                    OT               Flight On Time                  OT
# 12                    OT               Flight On Time                  OT
# 13                    OT               Flight On Time                  OT
# 14                    OT               Flight On Time                  OT
# 15                    OT               Flight On Time                  OT
# 16                    OT               Flight On Time                  OT
# 17                    OT               Flight On Time                  OT
# 18                    OT               Flight On Time                  OT
# 19                    OT               Flight On Time                  OT
# 20                    OT               Flight On Time                  OT
# 21                    OT               Flight On Time                  OT
# 22                    OT               Flight On Time                  OT
# 23                    OT               Flight On Time                  OT
# 24                    OT               Flight On Time                  OT
# 25                    OT               Flight On Time                  OT
# 26                    OT               Flight On Time                  OT
# 27                    OT               Flight On Time                  OT
# 28                    OT               Flight On Time                  OT
# 29                    OT               Flight On Time                  OT
# 30                    OT               Flight On Time                  OT
# 31                    OT               Flight On Time                  OT
#
#    Status_Description_Arrival
# 0              Flight On Time
# 1              Flight On Time
# 2              Flight On Time
# 3              Flight On Time
# 4              Flight On Time
# 5              Flight On Time
# 6              Flight On Time
# 7              Flight On Time
# 8              Flight On Time
# 9              Flight On Time
# 10             Flight On Time
# 11             Flight On Time
# 12             Flight On Time
# 13             Flight On Time
# 14             Flight On Time
# 15             Flight On Time
# 16             Flight On Time
# 17             Flight On Time
# 18             Flight On Time
# 19             Flight On Time
# 20             Flight On Time
# 21             Flight On Time
# 22             Flight On Time
# 23             Flight On Time
# 24             Flight On Time
# 25             Flight On Time
# 26             Flight On Time
# 27             Flight On Time
# 28             Flight On Time
# 29             Flight On Time
# 30             Flight On Time
# 31             Flight On Time
